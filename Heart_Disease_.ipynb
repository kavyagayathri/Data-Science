# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyagayathri/Data-Science/blob/main/Heart_Disease_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd .read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.head(5)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.drop('ChestPainType',axis=1)
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     40   M        140          289          0     Normal    172
# 1     49   F        160          180          0     Normal    156
# 2     37   M        130          283          0         ST     98
# 3     48   F        138          214          0     Normal    108
# 4     54   M        150          195          0     Normal    122
# ..   ...  ..        ...          ...        ...        ...    ...
# 913   45   M        110          264          0     Normal    132
# 914   68   M        144          193          1     Normal    141
# 915   57   M        130          131          0     Normal    115
# 916   57   F        130          236          0        LVH    174
# 917   38   M        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0                N      0.0       Up             0
# 1                N      1.0     Flat             1
# ...

# %%
X=df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.head()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 155   56   M           ASY        155          342          1     Normal
# 362   56   M           NAP        155            0          0         ST
# 869   59   M           NAP        150          212          1     Normal
# 101   51   M           ASY        130          179          0     Normal
# 199   57   F            TA        130          308          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# 155    150              Y      3.0     Flat
# 362     99              N      0.0     Flat
# 869    157              N      1.6       Up
# 101    100              N      0.0       Up
# 199     98              N      1.0     Flat

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
X_train.shape
# Out:
# (688, 11)

# %%
X_train.head()
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 155   56   M        155          342          1     Normal    150
# 362   56   M        155            0          0         ST     99
# 869   59   M        150          212          1     Normal    157
# 101   51   M        130          179          0     Normal    100
# 199   57   F        130          308          0     Normal     98
#
#     ExerciseAngina  Oldpeak ST_Slope
# 155              Y      3.0     Flat
# 362              N      0.0     Flat
# 869              N      1.6       Up
# 101              N      0.0       Up
# 199              N      1.0     Flat

# %%
X_train.drop('ChestPainType',axis=1,inplace=True)

# %%
df['RestingECG'].mode()
# Out:
# 0    Normal
# Name: RestingECG, dtype: object

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
X_train.head()
# Out:
#      Age Sex  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 155   56   M        155          342          1     Normal    150
# 362   56   M        155            0          0         ST     99
# 869   59   M        150          212          1     Normal    157
# 101   51   M        130          179          0     Normal    100
# 199   57   F        130          308          0     Normal     98
#
#     ExerciseAngina  Oldpeak ST_Slope
# 155              Y      3.0     Flat
# 362              N      0.0     Flat
# 869              N      1.6       Up
# 101              N      0.0       Up
# 199              N      1.0     Flat

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

X_train['Sex'] = encoder.fit_transform(X_train['Sex'])
X_train['RestingECG'] = encoder.fit_transform(X_train['RestingECG'])
X_train['ExerciseAngina'] = encoder.fit_transform(X_train['ExerciseAngina'])
X_train['ST_Slope'] = encoder.fit_transform(X_train['ST_Slope'])

# %%
X_train.head()
# Out:
#      Age  Sex  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 155   56    1        155          342          1           1    150
# 362   56    1        155            0          0           2     99
# 869   59    1        150          212          1           1    157
# 101   51    1        130          179          0           1    100
# 199   57    0        130          308          0           1     98
#
#      ExerciseAngina  Oldpeak  ST_Slope
# 155               1      3.0         1
# 362               0      0.0         1
# 869               0      1.6         2
# 101               0      0.0         2
# 199               0      1.0         1

# %%
X_train.corr()
# Out:
#                      Age       Sex  RestingBP  Cholesterol  FastingBS  \
# Age             1.000000  0.086271   0.286645    -0.108778   0.223373
# Sex             0.086271  1.000000   0.053828    -0.201268   0.117870
# RestingBP       0.286645  0.053828   1.000000     0.083419   0.078376
# Cholesterol    -0.108778 -0.201268   0.083419     1.000000  -0.255651
# FastingBS       0.223373  0.117870   0.078376    -0.255651   1.000000
# RestingECG      0.001169  0.076567   0.027113    -0.205483   0.083707
# MaxHR          -0.389496 -0.199689  -0.137255     0.247929  -0.148766
# ExerciseAngina  0.244845  0.213867   0.190511    -0.035848   0.075265
# Oldpeak         0.282863  0.127476   0.173326     0.049254   0.044515
# ST_Slope       -0.285068 -0.168706  -0.097338     0.138043  -0.186364
#
#                 RestingECG     MaxHR  ExerciseAngina   Oldpeak  ST_Slope
# Age               0.001169 -0.389496        0.244845  0.282863 -0.285068
# ...

# %%
sns.heatmap(X_train.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_train)

# %%
mean_squared_error(y_train,y_pred)
# Out:
# 0.12390928308707523

# %%
r2_score(y_train,y_pred)
# Out:
# 0.5000365206153801

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score

# %%
lr_model = LogisticRegression()

lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
lr_model.score(X_train, y_train)
# Out:
# 0.8531976744186046

# %%
y_train_pred = lr_model.predict(X_train)
print(accuracy_score(y_train, y_train_pred))
# Out:
# 0.8531976744186046

# %%
precision_score(y_train,y_train_pred)
# Out:
# 0.862796833773087

# %%
recall_score(y_train,y_train_pred)
# Out:
# 0.8696808510638298

# %%
from sklearn.svm import SVC

# %%
SVC_model = SVC()

SVC_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
SVC_model.score(X_train, y_train)
# Out:
# 0.7281976744186046
